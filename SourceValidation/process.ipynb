# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
test = pd.read_csv('test.csv/test.csv')
train = pd.read_csv('train.csv/train.csv')
FAKE = pd.read_csv("fake_news_fake_true/News _dataset/Fake.csv")
TRUE = pd.read_csv("fake_news_fake_true/News _dataset/True.csv")
ForR = pd.read_csv("fake_or_real_news.csv/fake_or_real_news.csv")

# %%
#now add a column to FAKE with the value of False in each row call it label
FAKE['label'] = False
TRUE['label'] = True

# %%
FAKE.head(20)
# Out:
#                                                 title  \
# 0    Donald Trump Sends Out Embarrassing New Year’...
# 1    Drunk Bragging Trump Staffer Started Russian ...
# 2    Sheriff David Clarke Becomes An Internet Joke...
# 3    Trump Is So Obsessed He Even Has Obama’s Name...
# 4    Pope Francis Just Called Out Donald Trump Dur...
# 5    Racist Alabama Cops Brutalize Black Boy While...
# 6    Fresh Off The Golf Course, Trump Lashes Out A...
# 7    Trump Said Some INSANELY Racist Stuff Inside ...
# 8    Former CIA Director Slams Trump Over UN Bully...
# 9    WATCH: Brand-New Pro-Trump Ad Features So Muc...
# 10   Papa John’s Founder Retires, Figures Out Raci...
# 11   WATCH: Paul Ryan Just Told Us He Doesn’t Care...
# 12   Bad News For Trump — Mitch McConnell Says No ...
# 13   WATCH: Lindsey Graham Trashes Media For Portr...
# 14   Heiress To Disney Empire Knows GOP Scammed Us...
# 15   Tone Deaf Trump: Congrats Rep. Scalise On Los...
# ...

# %%
#combine TRUE and FAKE
df = pd.concat([FAKE, TRUE]).reset_index(drop = True)

# %%
#add title to the end of text, and drop the title column
df['text'] = df['title'] + ' ' + df['text']
df = df.drop(['title'], axis=1)

# %%
#drop subject, and date values
df = df.drop(['subject', 'date'], axis=1)

# %%
df.head()
# Out:
#                                                 text  label
# 0   Donald Trump Sends Out Embarrassing New Year’...  False
# 1   Drunk Bragging Trump Staffer Started Russian ...  False
# 2   Sheriff David Clarke Becomes An Internet Joke...  False
# 3   Trump Is So Obsessed He Even Has Obama’s Name...  False
# 4   Pope Francis Just Called Out Donald Trump Dur...  False

# %%
subset1 = df

# %%
#combine test and train
df = train
df.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
#drop author, append title to the start of the text and remove the title column
df = df.drop(['author'], axis=1)
df['text'] = df['title'] + ' ' + df['text']
df = df.drop(['title'], axis=1)

# %%
df.head(20)
# Out:
#                                                  text  label
# 0   House Dem Aide: We Didn’t Even See Comey’s Let...  False
# 1   FLYNN: Hillary Clinton, Big Woman on Campus - ...   True
# 2   Why the Truth Might Get You Fired Why the Trut...  False
# 3   15 Civilians Killed In Single US Airstrike Hav...  False
# 4   Iranian woman jailed for fictional unpublished...  False
# 5   Jackie Mason: Hollywood Would Love Trump if He...   True
# 6   Life: Life Of Luxury: Elton John’s 6 Favorite ...  False
# 7   Benoît Hamon Wins French Socialist Party’s Pre...   True
# 8   Excerpts From a Draft Script for Donald Trump’...   True
# 9   A Back-Channel Plan for Ukraine and Russia, Co...   True
# 10  Obama’s Organizing for Action Partners with So...   True
# 11  BBC Comedy Sketch "Real Housewives of ISIS" Ca...   True
# 12  Russian Researchers Discover Secret Nazi Milit...  False
# 13  US Officials See No Link Between Trump and Rus...  False
# ...

# %%
#drop the id column
df.drop('id', axis=1, inplace=True)

# %%
#now set label values of one to false, and zero to true for the binary classification
df = df.replace({'label': {1: False, 0: True}})

# %%
subset2 = df

# %%
#combine the sub dataframes into one dataframe
df = pd.concat([subset1,subset2],axis=0)

# %%
df.describe()
# Out:
#                                                      text  label
# count                                               65101  65698
# unique                                              59237      2
# top     Highlights: The Trump presidency on April 13 a...  False
# freq                                                    8  33894

# %%
#export to csv
df.to_csv('data_Organized.csv', index=False)

# %%
#now we will clean the text data 
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
import re
stop_words = stopwords.words('english')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
stemmer    = nltk.SnowballStemmer("english")
# Out:
# [nltk_data] Downloading package stopwords to /home/james/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess(text):
    
    
    try:
        text = text.replace('\n', ' ')
        text = text.replace('\t', ' ')
        text = text.replace('  ', ' ')
        text = text.replace('   ', ' ')
        text = text.replace('    ', ' ')
        text = text.replace('     ', ' ')
        text = text.replace('      ', ' ')
        text = text.replace('       ', ' ')
        text = text.replace('        ', ' ')
        text = text.replace('         ', ' ')
        text = text.lower()
        text = re.sub('https?://\S+|www\.\S+', '', text) # remove urls
        text = re.sub('[%s]' % re.escape(string.punctuation), '', text) # remove punctuation
        text = re.sub('\n', '', text)
        text = re.sub('\w*\d\w*', '', text)

    #remove stopwords
        text = ' '.join(word for word in text.split() if word not in stop_words)    # Remove stopwords
        text = ' '.join(stemmer.stem(word) for word in text.split())   

    except:
        pass
    

    return text

# %%
df['text'] = df['text'].apply(lambda x: preprocess(x))

# %%
df.to_csv("cleaned_data.csv", index=False)
